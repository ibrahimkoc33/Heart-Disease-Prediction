# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from matplotlib import rcParams
from matplotlib.cm import rainbow
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

#Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

#KNN
from sklearn.neighbors import KNeighborsClassifier

#Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz

#NaiveBayes
from sklearn.naive_bayes import GaussianNB

#extreme gradient boost
from xgboost import XGBClassifier

#Tensorflow
import tensorflow as tf
from tensorflow.keras import regularizers

from sklearn.svm import SVC

# %%
data=pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
sns.histplot(data['age'], bins=20, kde=True)
plt.show()

# %%
for i in list(data.columns):
  print("{} --> {}".format(i,data[i].value_counts().shape[0]))
# Out:
# age --> 41
# sex --> 2
# cp --> 4
# trestbps --> 49
# chol --> 152
# fbs --> 2
# restecg --> 3
# thalach --> 91
# exang --> 2
# oldpeak --> 40
# slope --> 3
# ca --> 5
# thal --> 4
# target --> 2

# %%
### sütunların targeti hangi yönde etkilediğini gösteriyoruz .Veri setindeki sayısal sütunların birbirleri arasındaki korelasyonu gözlemliyoruz.
correlation_matrix=data.corr()
correlation_matrix["target"].sort_values()
# Out:
# oldpeak    -0.438441
# exang      -0.438029
# ca         -0.382085
# thal       -0.337838
# sex        -0.279501
# age        -0.229324
# trestbps   -0.138772
# chol       -0.099966
# fbs        -0.041164
# restecg     0.134468
# slope       0.345512
# thalach     0.422895
# cp          0.434854
# target      1.000000
# Name: target, dtype: float64

# %%
import seaborn as sns
correlation_matrix=data.corr()
top_corr_features=correlation_matrix.index
plt.figure(figsize=(12,8))
sns.heatmap(data[top_corr_features].corr(),annot=True,cmap='RdYlGn')
plt.show()

# %% [markdown]
# **Data Processing**

# %%
#ONE HOT ENCODER: kategorik olan sütunlar one-hot encoding ile dönüştürülüyor. Her bir kategorik değer, ayrı bir sütun haline getirilir ve bu sütunlar 0 veya 1 değerlerini alır.
#Bu, makine öğrenimi algoritmalarının kategorik verilerle çalışmasını kolaylaştırır.
columns_to_encode=["sex","cp","fbs","restecg","exang","slope","ca","thal"]
dataset=pd.get_dummies(data,columns=columns_to_encode)

# %%
# Normalizasyon sayısal özellikler (age, trestbps, chol, thalach, oldpeak) StandardScaler kullanılarak normalize edilir.
#Normalizasyon, özelliklerin aynı ölçeğe sahip olmasını sağlar, bu da birçok makine öğrenimi algoritması için önemlidir.
scaler=StandardScaler()
columns_to_scale=['age','trestbps','chol','thalach','oldpeak']
dataset[columns_to_scale]=scaler.fit_transform(dataset[columns_to_scale])

# %%
y=dataset['target']
x=dataset.drop(['target'],axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=5)

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
logreg=LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred_prob=logreg.predict_proba(x_test)
ypred=np.argmax(ypred_prob,axis=1)
dummy=pd.DataFrame(ypred_prob)
dummy["ypred"]=ypred
dummy.head()
# Out:
#           0         1  ypred
# 0  0.065136  0.934864      1
# 1  0.502345  0.497655      0
# 2  0.707733  0.292267      0
# 3  0.978017  0.021983      0
# 4  0.267778  0.732222      1

# %%
logreg_predict = logreg.predict(x_test)
logreg_conf_matrix = confusion_matrix(y_test, logreg_predict)
logreg_acc_score = accuracy_score(y_test, logreg_predict)
print("CONFUSSION MATRIX")
print(logreg_conf_matrix,"\n")
print("CLASSIFICATION REPORT:")
print(classification_report(y_test,logreg_predict))
# Out:
# CONFUSSION MATRIX
# [[138  28]
#  [ 12 161]]
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87       166
#            1       0.85      0.93      0.89       173
#
#     accuracy                           0.88       339
#    macro avg       0.89      0.88      0.88       339
# weighted avg       0.89      0.88      0.88       339

# %%
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
cm=metrics.confusion_matrix(y_true=y_test,y_pred=logreg_predict)
plot_confusion_matrix(conf_mat=cm,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      figsize=(4,4))

plt.show()

# %%
print("Accuracy of Logistic Regression:",logreg_acc_score*100,'\n')
# Out:
# Accuracy of Logistic Regression: 88.20058997050147

# %%
score=cross_val_score(logreg,x,y,cv=5)
print("Cross-Validation Mean Score:", score.mean()*100)
# Out:
# Cross-Validation Mean Score: 85.85365853658537

# %% [markdown]
# **KNN**

# %%
knn_scores=[]
for k in range(1,21):
  knn=KNeighborsClassifier(n_neighbors=k)
  knn.fit(x_train,y_train)
  knn_scores.append(knn.score(x_test,y_test))

# %%
plt.plot([k for k in range(1,21)],knn_scores)
for i in range(1,21):
  plt.text(i,knn_scores[i-1],(i,knn_scores[i-1]),fontsize='6')
plt.xticks([i for i in range(1,21)])
plt.xlabel('Number of Neighbors (K)',color='Red',weight='bold',fontsize='12')
plt.ylabel('Scores',color='Red',weight='bold',fontsize='12')
plt.title('K Neighbors Classifier scores for different K values',color='Red',weight='bold',fontsize='12')
plt.show()
plt.rcParams["font.weight"]="bold"
plt.rcParams["axes.labelweight"]="bold"

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
knn_predict = knn.predict(x_test)
knn_acc_score = accuracy_score(y_test, knn_predict)
print("CONFUSSION MATRIX")
print(confusion_matrix(y_test, knn_predict),"\n")
print("CLASSIFICATION REPORT:")
print(classification_report(y_test,knn_predict))
# Out:
# CONFUSSION MATRIX
# [[141  25]
#  [ 18 155]]
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87       166
#            1       0.86      0.90      0.88       173
#
#     accuracy                           0.87       339
#    macro avg       0.87      0.87      0.87       339
# weighted avg       0.87      0.87      0.87       339

# %%
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
cm=metrics.confusion_matrix(y_true=y_test,y_pred=knn_predict)
plot_confusion_matrix(conf_mat=cm,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      figsize=(4,4))

plt.show()

# %%
print("Accuracy of kNN:",knn_acc_score*100,'\n')
# Out:
# Accuracy of kNN: 87.31563421828909

# %%
score=cross_val_score(knn,x,y,cv=10)
print("Cross-Validation Mean Score:", score.mean()*100)
# Out:
# Cross-Validation Mean Score: 87.70607272035026

# %% [markdown]
# **RANDOM FOREST**

# %%
randomForest = RandomForestClassifier(n_estimators=20, random_state=12,max_depth=7)

# %%
randomForest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=7, n_estimators=20, random_state=12)

# %%
randomForest_y_pred=randomForest.predict(x_test)
randomForest_y_pred_quant=randomForest.predict_proba(x_test)[:,1]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       166
#            1       0.95      0.99      0.97       173
#
#     accuracy                           0.97       339
#    macro avg       0.97      0.97      0.97       339
# weighted avg       0.97      0.97      0.97       339

# %%
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
cm=metrics.confusion_matrix(y_true=y_test,y_pred=y_pred)
plot_confusion_matrix(conf_mat=cm,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      figsize=(4,4))

plt.show()

# %%
randomForest_acc_score = accuracy_score(y_test, randomForest_y_pred)
print("Accuracy:",metrics.accuracy_score(y_true=y_test,y_pred=y_pred)*100,"\n")
# Out:
# Accuracy: 97.05014749262537

# %%
score=cross_val_score(randomForest,x,y,cv=7)
print("Cross-Validation Mean Score:", score.mean()*100)
# Out:
# Cross-Validation Mean Score: 97.16841726906027

# %% [markdown]
# **NAIVE BAYES**

# %%
naiveBayes = GaussianNB()
naiveBayes.fit(x_train,y_train)
naiveBayes_pred = naiveBayes.predict(x_test)
naiveBayes_conf_matrix = confusion_matrix(y_test, naiveBayes_pred)
naiveBayes_acc_score = accuracy_score(y_test, naiveBayes_pred)
print("confussion matrix")
print(naiveBayes_conf_matrix,"\n")
print("CLASSIFICATION REPORT:")
print(classification_report(y_test,naiveBayes_pred))
# Out:
# confussion matrix
# [[129  37]
#  [ 16 157]]
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83       166
#            1       0.81      0.91      0.86       173
#
#     accuracy                           0.84       339
#    macro avg       0.85      0.84      0.84       339
# weighted avg       0.85      0.84      0.84       339

# %%
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
cm=metrics.confusion_matrix(y_true=y_test,y_pred=naiveBayes_pred)
plot_confusion_matrix(conf_mat=cm,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      figsize=(4,4))

plt.show()

# %%
print("Accuracy of Naive Bayes model:",naiveBayes_acc_score*100,'\n')
# Out:
# Accuracy of Naive Bayes model: 84.36578171091446

# %%
score=cross_val_score(naiveBayes,x,y,cv=7)
print("Cross-Validation Mean Score:", score.mean()*100)
# Out:
# Cross-Validation Mean Score: 84.1953219644022

# %% [markdown]
# **EXTREME GRADIENT BOOST**

# %%
m4 = 'Extreme Gradient Boost'
xgb = XGBClassifier(learning_rate=0.01, n_estimators=75, max_depth=20,gamma=0.8, subsample=0.52,colsample_bytree=0.6,seed=27,
                    reg_lambda=2, booster='dart', colsample_bylevel=0.6, colsample_bynode=0.5)
xgb.fit(x_train, y_train)
xgb_predicted = xgb.predict(x_test)
xgb_conf_matrix = confusion_matrix(y_test, xgb_predicted)
xgb_acc_score = accuracy_score(y_test, xgb_predicted)
print("confussion matrix")
print(xgb_conf_matrix,"\n")
print("CLASSIFICATION REPORT:")
print(classification_report(y_test,xgb_predicted))
# Out:
# confussion matrix
# [[133  33]
#  [  8 165]]
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.87       166
#            1       0.83      0.95      0.89       173
#
#     accuracy                           0.88       339
#    macro avg       0.89      0.88      0.88       339
# weighted avg       0.89      0.88      0.88       339

# %%
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
cm=metrics.confusion_matrix(y_true=y_test,y_pred=xgb_predicted)
plot_confusion_matrix(conf_mat=cm,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      figsize=(4,4))

plt.show()

# %%
print("Accuracy of Extreme Gradient Boost:",xgb_acc_score*100,'\n')
# Out:
# Accuracy of Extreme Gradient Boost: 87.90560471976401

# %%
score=cross_val_score(xgb,x,y,cv=7)
print("Cross-Validation Mean Score:", score.mean()*100)
# Out:
# Cross-Validation Mean Score: 89.654139542314

# %% [markdown]
# **ARTIFICAL NEURAL NETWORK-- TENSORFLOW**

# %%
def create_tf_model():
  tf_model=tf.keras.models.Sequential([
      tf.keras.layers.Dense(64, activation='relu', input_dim=x_train.shape[1], kernel_regularizer=regularizers.l2(0.008)),
      tf.keras.layers.Dropout(0,5),
      tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.008)),
      tf.keras.layers.Dropout(0,5),
      tf.keras.layers.Dense(1, activation='sigmoid')
  ])
  return tf_model
model=create_tf_model()

# %%
from tensorflow.keras.optimizers import Adam
model.compile(loss="binary_crossentropy", optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])

# %%
model.fit(x=x_train,y=y_train, validation_data = (x_test,y_test),epochs=100, batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 1s 13ms/step - loss: 1.2352 - accuracy: 0.6516 - val_loss: 1.1178 - val_accuracy: 0.7817
# Epoch 2/100
# 22/22 [==============================] - 0s 4ms/step - loss: 1.0331 - accuracy: 0.8076 - val_loss: 0.9454 - val_accuracy: 0.8171
# Epoch 3/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8794 - accuracy: 0.8455 - val_loss: 0.8173 - val_accuracy: 0.8584
# Epoch 4/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.7672 - accuracy: 0.8557 - val_loss: 0.7264 - val_accuracy: 0.8702
# Epoch 5/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.8586 - val_loss: 0.6583 - val_accuracy: 0.8732
# Epoch 6/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6299 - accuracy: 0.8659 - val_loss: 0.6072 - val_accuracy: 0.8879
# Epoch 7/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5839 - accuracy: 0.8659 - val_loss: 0.5637 - val_accuracy: 0.8791
# Epoch 8/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.5443 - accuracy: 0.8644 - val_loss: 0.5323 - val_accuracy: 0.8791
# Epoch 9/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.5151 - accuracy: 0.8776 - val_loss: 0.5025 - val_accuracy: 0.8820
# Epoch 10/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4873 - accuracy: 0.8790 - val_loss: 0.4806 - val_accuracy: 0.8909
# Epoch 11/100
# 22/22 [==============================] - 0s 11ms/step - loss: 0.4671 - accuracy: 0.8834 - val_loss: 0.4646 - val_accuracy: 0.8791
# Epoch 12/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.4490 - accuracy: 0.8848 - val_loss: 0.4444 - val_accuracy: 0.9027
# Epoch 13/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.4337 - accuracy: 0.8892 - val_loss: 0.4291 - val_accuracy: 0.8909
# Epoch 14/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.4185 - accuracy: 0.8965 - val_loss: 0.4190 - val_accuracy: 0.8968
# Epoch 15/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4075 - accuracy: 0.8892 - val_loss: 0.4057 - val_accuracy: 0.9056
# Epoch 16/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3970 - accuracy: 0.9052 - val_loss: 0.4005 - val_accuracy: 0.8997
# Epoch 17/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3874 - accuracy: 0.8980 - val_loss: 0.3929 - val_accuracy: 0.8968
# Epoch 18/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3787 - accuracy: 0.8980 - val_loss: 0.3860 - val_accuracy: 0.9027
# Epoch 19/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3710 - accuracy: 0.8921 - val_loss: 0.3754 - val_accuracy: 0.9086
# Epoch 20/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3653 - accuracy: 0.9140 - val_loss: 0.3699 - val_accuracy: 0.9115
# Epoch 21/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3600 - accuracy: 0.9125 - val_loss: 0.3636 - val_accuracy: 0.9145
# Epoch 22/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3526 - accuracy: 0.9184 - val_loss: 0.3622 - val_accuracy: 0.9086
# Epoch 23/100
# 22/22 [==============================] - 0s 11ms/step - loss: 0.3499 - accuracy: 0.9038 - val_loss: 0.3548 - val_accuracy: 0.9174
# Epoch 24/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.3429 - accuracy: 0.9184 - val_loss: 0.3546 - val_accuracy: 0.9115
# Epoch 25/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3383 - accuracy: 0.9227 - val_loss: 0.3456 - val_accuracy: 0.9204
# Epoch 26/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.3344 - accuracy: 0.9213 - val_loss: 0.3424 - val_accuracy: 0.9145
# Epoch 27/100
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3281 - accuracy: 0.9198 - val_loss: 0.3383 - val_accuracy: 0.9174
# Epoch 28/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.3268 - accuracy: 0.9227 - val_loss: 0.3336 - val_accuracy: 0.9204
# Epoch 29/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.3217 - accuracy: 0.9213 - val_loss: 0.3319 - val_accuracy: 0.9174
# Epoch 30/100
# 22/22 [==============================] - 0s 21ms/step - loss: 0.3172 - accuracy: 0.9257 - val_loss: 0.3273 - val_accuracy: 0.9263
# Epoch 31/100
# 22/22 [==============================] - 1s 24ms/step - loss: 0.3149 - accuracy: 0.9271 - val_loss: 0.3294 - val_accuracy: 0.9204
# Epoch 32/100
# 22/22 [==============================] - 0s 20ms/step - loss: 0.3073 - accuracy: 0.9271 - val_loss: 0.3190 - val_accuracy: 0.9204
# Epoch 33/100
# 22/22 [==============================] - 0s 20ms/step - loss: 0.3032 - accuracy: 0.9315 - val_loss: 0.3168 - val_accuracy: 0.9292
# Epoch 34/100
# 22/22 [==============================] - 0s 15ms/step - loss: 0.2997 - accuracy: 0.9344 - val_loss: 0.3138 - val_accuracy: 0.9233
# Epoch 35/100
# 22/22 [==============================] - 0s 15ms/step - loss: 0.2993 - accuracy: 0.9388 - val_loss: 0.3130 - val_accuracy: 0.9292
# Epoch 36/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2931 - accuracy: 0.9373 - val_loss: 0.3055 - val_accuracy: 0.9351
# Epoch 37/100
# 22/22 [==============================] - 0s 11ms/step - loss: 0.2907 - accuracy: 0.9329 - val_loss: 0.3071 - val_accuracy: 0.9322
# Epoch 38/100
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2864 - accuracy: 0.9402 - val_loss: 0.3066 - val_accuracy: 0.9292
# Epoch 39/100
# 22/22 [==============================] - 0s 11ms/step - loss: 0.2827 - accuracy: 0.9388 - val_loss: 0.2970 - val_accuracy: 0.9381
# Epoch 40/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2843 - accuracy: 0.9446 - val_loss: 0.2937 - val_accuracy: 0.9440
# Epoch 41/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2770 - accuracy: 0.9431 - val_loss: 0.2916 - val_accuracy: 0.9469
# Epoch 42/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2712 - accuracy: 0.9461 - val_loss: 0.3047 - val_accuracy: 0.9322
# Epoch 43/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2725 - accuracy: 0.9475 - val_loss: 0.2891 - val_accuracy: 0.9381
# Epoch 44/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2661 - accuracy: 0.9504 - val_loss: 0.2842 - val_accuracy: 0.9440
# Epoch 45/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2638 - accuracy: 0.9504 - val_loss: 0.2850 - val_accuracy: 0.9410
# Epoch 46/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2632 - accuracy: 0.9519 - val_loss: 0.2835 - val_accuracy: 0.9410
# Epoch 47/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2641 - accuracy: 0.9519 - val_loss: 0.2868 - val_accuracy: 0.9440
# Epoch 48/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2598 - accuracy: 0.9504 - val_loss: 0.2772 - val_accuracy: 0.9469
# Epoch 49/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2543 - accuracy: 0.9606 - val_loss: 0.2774 - val_accuracy: 0.9469
# Epoch 50/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2538 - accuracy: 0.9519 - val_loss: 0.2804 - val_accuracy: 0.9410
# Epoch 51/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2505 - accuracy: 0.9592 - val_loss: 0.2652 - val_accuracy: 0.9617
# Epoch 52/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2476 - accuracy: 0.9606 - val_loss: 0.2660 - val_accuracy: 0.9646
# Epoch 53/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2478 - accuracy: 0.9621 - val_loss: 0.2616 - val_accuracy: 0.9617
# Epoch 54/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2436 - accuracy: 0.9592 - val_loss: 0.2598 - val_accuracy: 0.9646
# Epoch 55/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2363 - accuracy: 0.9650 - val_loss: 0.2697 - val_accuracy: 0.9499
# Epoch 56/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2349 - accuracy: 0.9665 - val_loss: 0.2557 - val_accuracy: 0.9676
# Epoch 57/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2358 - accuracy: 0.9665 - val_loss: 0.2551 - val_accuracy: 0.9646
# Epoch 58/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2318 - accuracy: 0.9694 - val_loss: 0.2584 - val_accuracy: 0.9558
# Epoch 59/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2342 - accuracy: 0.9665 - val_loss: 0.2596 - val_accuracy: 0.9646
# Epoch 60/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2267 - accuracy: 0.9708 - val_loss: 0.2673 - val_accuracy: 0.9587
# Epoch 61/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2307 - accuracy: 0.9621 - val_loss: 0.2542 - val_accuracy: 0.9735
# Epoch 62/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2271 - accuracy: 0.9738 - val_loss: 0.2451 - val_accuracy: 0.9676
# Epoch 63/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.2236 - accuracy: 0.9679 - val_loss: 0.2437 - val_accuracy: 0.9735
# Epoch 64/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2233 - accuracy: 0.9723 - val_loss: 0.2418 - val_accuracy: 0.9676
# Epoch 65/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2193 - accuracy: 0.9767 - val_loss: 0.2411 - val_accuracy: 0.9764
# Epoch 66/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2146 - accuracy: 0.9767 - val_loss: 0.2377 - val_accuracy: 0.9676
# Epoch 67/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2129 - accuracy: 0.9723 - val_loss: 0.2349 - val_accuracy: 0.9705
# Epoch 68/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2163 - accuracy: 0.9767 - val_loss: 0.2354 - val_accuracy: 0.9735
# Epoch 69/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2120 - accuracy: 0.9796 - val_loss: 0.2308 - val_accuracy: 0.9705
# Epoch 70/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2083 - accuracy: 0.9854 - val_loss: 0.2310 - val_accuracy: 0.9705
# Epoch 71/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2041 - accuracy: 0.9825 - val_loss: 0.2282 - val_accuracy: 0.9735
# Epoch 72/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2039 - accuracy: 0.9854 - val_loss: 0.2279 - val_accuracy: 0.9735
# Epoch 73/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2030 - accuracy: 0.9810 - val_loss: 0.2236 - val_accuracy: 0.9764
# Epoch 74/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.2005 - accuracy: 0.9854 - val_loss: 0.2247 - val_accuracy: 0.9794
# Epoch 75/100
# 22/22 [==============================] - 0s 15ms/step - loss: 0.2016 - accuracy: 0.9810 - val_loss: 0.2220 - val_accuracy: 0.9705
# Epoch 76/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1978 - accuracy: 0.9840 - val_loss: 0.2183 - val_accuracy: 0.9764
# Epoch 77/100
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2000 - accuracy: 0.9825 - val_loss: 0.2206 - val_accuracy: 0.9735
# Epoch 78/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1960 - accuracy: 0.9840 - val_loss: 0.2236 - val_accuracy: 0.9735
# Epoch 79/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1932 - accuracy: 0.9825 - val_loss: 0.2142 - val_accuracy: 0.9853
# Epoch 80/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1919 - accuracy: 0.9898 - val_loss: 0.2120 - val_accuracy: 0.9823
# Epoch 81/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1931 - accuracy: 0.9854 - val_loss: 0.2139 - val_accuracy: 0.9823
# Epoch 82/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1892 - accuracy: 0.9913 - val_loss: 0.2127 - val_accuracy: 0.9853
# Epoch 83/100
# 22/22 [==============================] - 0s 17ms/step - loss: 0.1902 - accuracy: 0.9869 - val_loss: 0.2201 - val_accuracy: 0.9705
# Epoch 84/100
# 22/22 [==============================] - 0s 18ms/step - loss: 0.1903 - accuracy: 0.9869 - val_loss: 0.2128 - val_accuracy: 0.9735
# Epoch 85/100
# 22/22 [==============================] - 0s 12ms/step - loss: 0.1849 - accuracy: 0.9898 - val_loss: 0.2216 - val_accuracy: 0.9676
# Epoch 86/100
# 22/22 [==============================] - 0s 20ms/step - loss: 0.1886 - accuracy: 0.9840 - val_loss: 0.2089 - val_accuracy: 0.9794
# Epoch 87/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.1842 - accuracy: 0.9883 - val_loss: 0.2053 - val_accuracy: 0.9882
# Epoch 88/100
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1820 - accuracy: 0.9898 - val_loss: 0.2035 - val_accuracy: 0.9882
# Epoch 89/100
# 22/22 [==============================] - 0s 14ms/step - loss: 0.1798 - accuracy: 0.9883 - val_loss: 0.2053 - val_accuracy: 0.9823
# Epoch 90/100
# 22/22 [==============================] - 1s 24ms/step - loss: 0.1802 - accuracy: 0.9869 - val_loss: 0.2019 - val_accuracy: 0.9882
# Epoch 91/100
# 22/22 [==============================] - 0s 23ms/step - loss: 0.1823 - accuracy: 0.9927 - val_loss: 0.2005 - val_accuracy: 0.9853
# Epoch 92/100
# 22/22 [==============================] - 0s 13ms/step - loss: 0.1769 - accuracy: 0.9854 - val_loss: 0.1975 - val_accuracy: 0.9823
# Epoch 93/100
# 22/22 [==============================] - 0s 16ms/step - loss: 0.1780 - accuracy: 0.9927 - val_loss: 0.2002 - val_accuracy: 0.9823
# Epoch 94/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.1739 - accuracy: 0.9913 - val_loss: 0.2111 - val_accuracy: 0.9794
# Epoch 95/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1755 - accuracy: 0.9869 - val_loss: 0.1964 - val_accuracy: 0.9823
# Epoch 96/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1732 - accuracy: 0.9883 - val_loss: 0.1966 - val_accuracy: 0.9823
# Epoch 97/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1729 - accuracy: 0.9898 - val_loss: 0.1975 - val_accuracy: 0.9823
# Epoch 98/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.1726 - accuracy: 0.9913 - val_loss: 0.1923 - val_accuracy: 0.9882
# Epoch 99/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.1718 - accuracy: 0.9913 - val_loss: 0.1919 - val_accuracy: 0.9823
# Epoch 100/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1700 - accuracy: 0.9927 - val_loss: 0.1893 - val_accuracy: 0.9882

# %%
modelkaybi=pd.DataFrame(model.history.history)

# %%
modelkaybi.plot()
# Out:
# <Axes: >

# %%
tf_y_pred = model.predict(x_test)
tf_y_pred_binary = (tf_y_pred > 0.5).astype(int)

# Confusion Matrix ve Diğer Metrikler
conf_matrix = confusion_matrix(y_test, tf_y_pred_binary)
tf_acc_score = accuracy_score(y_test, tf_y_pred_binary)

print("CONFUSION MATRIX:")
print(conf_matrix, "\n")

print("CLASSIFICATION REPORT:")
print(classification_report(y_test, tf_y_pred_binary))
# Out:
# 11/11 [==============================] - 0s 2ms/step
# CONFUSION MATRIX:
# [[162   4]
#  [  0 173]]
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       166
#            1       0.98      1.00      0.99       173
#
#     accuracy                           0.99       339
#    macro avg       0.99      0.99      0.99       339
# weighted avg       0.99      0.99      0.99       339

# %%
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
cm=metrics.confusion_matrix(y_true=y_test,y_pred=tf_y_pred_binary)
plot_confusion_matrix(conf_mat=cm,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      figsize=(4,4))

plt.show()

# %%
print("Accuracy of TensorFlow Model:", tf_acc_score * 100, '\n')
# Out:
# Accuracy of TensorFlow Model: 98.82005899705014

# %% [markdown]
# **DECISION TREE**

# %%
decTree = DecisionTreeClassifier(criterion = 'entropy',random_state=0,max_depth = 6)
decTree.fit(x_train, y_train)
decTree_predicted = decTree.predict(x_test)
decTree_conf_matrix = confusion_matrix(y_test, decTree_predicted)
decTree_acc_score = accuracy_score(y_test, decTree_predicted)
print("CONFUSION MATRIX:")
print(decTree_conf_matrix,"\n")

print("CLASSIFICATION REPORT:")
print(classification_report(y_test,decTree_predicted))
# Out:
# CONFUSION MATRIX:
# [[157   9]
#  [  9 164]]
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       166
#            1       0.95      0.95      0.95       173
#
#     accuracy                           0.95       339
#    macro avg       0.95      0.95      0.95       339
# weighted avg       0.95      0.95      0.95       339

# %%
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
cm=metrics.confusion_matrix(y_true=y_test,y_pred=decTree_predicted)
plot_confusion_matrix(conf_mat=cm,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      figsize=(4,4))

plt.show()

# %%
print("Accuracy of DecisionTreeClassifier:",decTree_acc_score*100,'\n')
# Out:
# Accuracy of DecisionTreeClassifier: 94.69026548672566

# %%
score=cross_val_score(decTree,x,y,cv=7)
print("Cross-Validation Mean Score:", score.mean()*100)
# Out:
# Cross-Validation Mean Score: 94.04861749004885

# %% [markdown]
# **SUPPORT VECTOR**

# %%
supportVector =  SVC(kernel='rbf', C=2)
supportVector.fit(x_train, y_train)
supportVector_predicted = supportVector.predict(x_test)
supportVector_conf_matrix = confusion_matrix(y_test, supportVector_predicted)
supportVector_acc_score = accuracy_score(y_test, supportVector_predicted)
print("CONFUSION MATRIX:")
print(supportVector_conf_matrix,"\n")

print("CLASSIFICATION REPORT:")
print(classification_report(y_test,supportVector_predicted))
# Out:
# CONFUSION MATRIX:
# [[153  13]
#  [  4 169]]
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95       166
#            1       0.93      0.98      0.95       173
#
#     accuracy                           0.95       339
#    macro avg       0.95      0.95      0.95       339
# weighted avg       0.95      0.95      0.95       339

# %%
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix
cm=metrics.confusion_matrix(y_true=y_test,y_pred=supportVector_predicted)
plot_confusion_matrix(conf_mat=cm,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      figsize=(4,4))

plt.show()

# %%
print("Accuracy of Support Vector Classifier:",supportVector_acc_score*100,'\n')
# Out:
# Accuracy of Support Vector Classifier: 94.98525073746312

# %%
score=cross_val_score(supportVector,x,y,cv=7)
print("Cross-Validation Mean Score:", score.mean()*100)
# Out:
# Cross-Validation Mean Score: 95.02110041668331

# %%
model_ev = pd.DataFrame({'Model': ['Logistic Regression','Naive Bayes','Random Forest','Extreme Gradient Boost',
                    'K-Nearest Neighbour','Decision Tree','Support Vector Machine'], 'Accuracy': [logreg_acc_score*100,
                    naiveBayes_acc_score*100,randomForest_acc_score*100,xgb_acc_score*100,knn_acc_score*100,decTree_acc_score*100,supportVector_acc_score*100]})
model_ev
# Out:
#                     Model   Accuracy
# 0     Logistic Regression  88.200590
# 1             Naive Bayes  84.365782
# 2           Random Forest  97.050147
# 3  Extreme Gradient Boost  87.905605
# 4     K-Nearest Neighbour  87.315634
# 5           Decision Tree  94.690265
# 6  Support Vector Machine  94.985251

# %% [markdown]
# Bu kod, StackingCVClassifier'ın kullanımını gösterir. Stacking, birden çok modelin tahminlerini birleştirerek daha güçlü bir model oluşturma yöntemidir.

# %%
from mlxtend.classifier import StackingCVClassifier
scv=StackingCVClassifier(classifiers=[logreg,knn,naiveBayes,xgb,randomForest,decTree,supportVector],meta_classifier= knn,random_state=42)
scv.fit(x_train,y_train)
scv_predicted = scv.predict(x_test)
scv_conf_matrix = confusion_matrix(y_test, scv_predicted)
scv_acc_score = accuracy_score(y_test, scv_predicted)
print("CONFUSION MATRIX:")
print(scv_conf_matrix,"\n")
print("Accuracy of StackingCVClassifier:",scv_acc_score*100,'\n')
print("CLASSIFICATION REPORT:")
print(classification_report(y_test,scv_predicted))
# Out:
# CONFUSION MATRIX:
# [[155  11]
#  [  2 171]]
#
# Accuracy of StackingCVClassifier: 96.16519174041298
#
# CLASSIFICATION REPORT:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       166
#            1       0.94      0.99      0.96       173
#
#     accuracy                           0.96       339
#    macro avg       0.96      0.96      0.96       339
# weighted avg       0.96      0.96      0.96       339
